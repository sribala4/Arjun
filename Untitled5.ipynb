# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#sns is built on top of matplotlib

# %%
SourceTech = pd.read_excel('SourceTech Bills.xlsx')

# %%
SourceTech
# Out:
#       Sl. No.       Number  Invoice               Name Document Date  \
# 0         1.0  PO-00033227  P 12206  Source Technologi    2020-02-20
# 1         2.0  PO-00027908   P 7897  Source Technologi    2019-10-26
# 2         3.0  PO-00034412    Q 484  Source Technologi    2020-05-16
# 3         4.0  PO-00018918   O 9593  Source Technologi    2018-12-04
# 4         5.0  PO-00017155   O 7536  Source Technologi    2018-10-27
# ...       ...          ...      ...                ...           ...
# 1603   1604.0  PO-00034353    Q 770  Source Technologi    2020-05-13
# 1604   1605.0  PO-00034353    Q 770  Source Technologi    2020-05-13
# 1605   1606.0  PO-00034353   Q 2038  Source Technologi    2020-05-13
# 1606   1607.0  PO-00035375     2036  Source Technologi    2020-07-09
# 1607      NaN          NaN      NaN                NaN           NaT
#
#      Packing slip  Batch number Product Receipt Date   Item number Unit  ...  \
# ...

# %%
SourceTech .dtypes
# Out:
# Sl. No.                         float64
# Number                           object
# Invoice                          object
# Name                             object
# Document Date            datetime64[ns]
# Packing slip                     object
# Batch number                     object
# Product Receipt Date     datetime64[ns]
# Item number                      object
# Unit                             object
# Financial date           datetime64[ns]
# Physical date            datetime64[ns]
# Purchase Price                  float64
# Currency                         object
# Line Amount                     float64
# Item Description                 object
# Warehouse                        object
# Location                         object
# Quantity                          int64
# Physical cost amount            float64
# Financial cost amount           float64
# dtype: object

# %% [markdown]
# Line graph

# %%
sns.lineplot(data=SourceTech)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20, 12))
sns.lineplot(data=SourceTech)
# Out:
# <Axes: >

# %%
SourceTech .shape
# Out:
# (1608, 21)

# %%
SourceTech[:10]
# Out:
#    Sl. No.       Number  Invoice               Name Document Date  \
# 0      1.0  PO-00033227  P 12206  Source Technologi    2020-02-20
# 1      2.0  PO-00027908   P 7897  Source Technologi    2019-10-26
# 2      3.0  PO-00034412    Q 484  Source Technologi    2020-05-16
# 3      4.0  PO-00018918   O 9593  Source Technologi    2018-12-04
# 4      5.0  PO-00017155   O 7536  Source Technologi    2018-10-27
# 5      6.0  PO-00023375   P 1143  Source Technologi    2019-04-30
# 6      7.0  PO-00020534  O 12024  Source Technologi    2019-01-31
# 7      8.0  PO-00025151   P 2823  Source Technologi    2019-06-12
# 8      9.0  PO-00034414   Q 1210  Source Technologi    2020-05-15
# 9     10.0  PO-00025703   P 4564  Source Technologi    2019-07-17
#
#   Packing slip  Batch number Product Receipt Date    Item number Unit  ...  \
# 0      P 12206  200225-00033           2020-02-25   RER004248-03  Nos  ...
# 1       P 7897  191031-00070           2019-10-31   REC013542-06  Nos  ...
# ...

# %%
SourceTech.isnull().sum()
# Out:
# Sl. No.                   1
# Number                    1
# Invoice                  61
# Name                      1
# Document Date            12
# Packing slip              1
# Batch number              1
# Product Receipt Date      2
# Item number               1
# Unit                      3
# Financial date            1
# Physical date             1
# Purchase Price            1
# Currency                  1
# Line Amount               1
# Item Description          1
# Warehouse                 1
# Location                  1
# Quantity                  0
# Physical cost amount      0
# Financial cost amount    60
# dtype: int64

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(data=SourceTech)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16, 8))
plt.title('Loss of Profit and Financial cost amount')
sns.lineplot(data=SourceTech['Quantity'], label = 'Desp')
sns.lineplot(data=SourceTech['Financial cost amount'], label = 'Unf')
plt.xlabel("from the Loss of Profit and Financial cost amount")
# Out:
# Text(0.5, 0, 'from the Loss of Profit and Financial cost amount')

# %%
plt.figure(figsize=(16, 8))
plt.title('Loss of Profit occurs 2023')
sns.lineplot(data=SourceTech['Invoice'], label = 'Desp')
sns.lineplot(data=SourceTech['Quantity'], label = 'Unf')
plt.xlabel("from the Loss of Profit occurs 2023")
# Out:
# Text(0.5, 0, 'from the Loss of Profit occurs 2023')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel('Forza.xlsx')
df.head(10)
# Out:
#    Sl. No.       Number            Invoice                    Name  \
# 0      1.0  PO-00032361               P891  Forza Industries P Ltd
# 1      2.0  PO-00032361    P907-26.02.2020  Forza Industries P Ltd
# 2      3.0  PO-00032361               P911  Forza Industries P Ltd
# 3      4.0  PO-00032361               P913  Forza Industries P Ltd
# 4      5.0  PO-00032361               P916  Forza Industries P Ltd
# 5      6.0  PO-00032361               P916  Forza Industries P Ltd
# 6      7.0  PO-00032361               P917  Forza Industries P Ltd
# 7      8.0  PO-00033715  PKG/SEZ/002/20-21  Forza Industries P Ltd
# 8      9.0  PO-00033715                P50  Forza Industries P Ltd
# 9     10.0  PO-00033715                P53  Forza Industries P Ltd
#
#   Document Date     Packing slip  Batch number Product Receipt Date  \
# 0    2020-02-21             P891  200221-00123           2020-02-21
# 1    2020-02-21  P907-26.02.2020  200227-00011           2020-02-21
# ...

# %%
df.describe()
# Out:
#            Sl. No.  Purchase Price    Line Amount       Quantity  \
# count  1247.000000     1247.000000    1247.000000    1248.000000
# mean    624.000000       48.762727   42883.675517     411.496795
# std     360.122201       41.519154   68722.149399    7269.773570
# min       1.000000        0.120000      40.000000    -800.000000
# 25%     312.500000       22.000000    6160.000000      50.000000
# 50%     624.000000       38.000000   15200.000000     106.000000
# 75%     935.500000       52.000000   44000.000000     223.250000
# max    1247.000000      180.000000  405000.000000  256774.000000
#
#        Physical cost amount  Financial cost amount  No\nof Months  \
# count          1.248000e+03           1.240000e+03          196.0
# mean           1.172929e+04           1.176864e+04            6.0
# std            2.071286e+05           2.071554e+05            0.0
# min           -1.800000e+03           4.000000e+01            6.0
# ...

# %%
plt.figure(figsize=(8,5))
plt.title("Line Amount",fontsize=16)
plt.xlabel ("Line Amount",fontsize=14)
plt.grid(True)
plt.hist(df['Line Amount'],color='orange',edgecolor='k')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Lossof\nQty Per Month",fontsize=16)
plt.xlabel ("Lossof\nQty Per Month",fontsize=14)
plt.grid(True)
plt.hist(df['Loss of\nQty Per Month'],color='Red',edgecolor='k')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Loss of\nQty Per Month",fontsize=16)
plt.xlabel ("Loss of\nQty Per Month",fontsize=14)
plt.grid(True)
plt.hist(df['Loss of\nQty Per Month'],color='pink',edgecolor='k')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Loss of\nQty Per Month and Loss\nof Amount\nper Month",fontsize=18)
plt.xlabel ("Loss of\nQty Per Month",fontsize=14)
plt.ylabel ("Loss\nof Amount\nper Month",fontsize=14)
plt.grid(True)
plt.scatter(df['Loss of\nQty Per Month'],df['Loss\nof Amount\nper Month'],color='red',edgecolor='k',alpha=0.6, s=100)
plt.show()

# %% [markdown]
# Dendograms

# %%
X = df.iloc[:,[3,4]].values

# %%
import scipy.cluster.hierarchy as sch

plt.figure(figsize=(15,6))
plt.title('Loss of Profit')
plt.xlabel('Financial cost amount')
plt.ylabel('Quantity')
#plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title('Dendrogram')
plt.xlabel('Loss of Profit')
plt.ylabel('Quantity')
plt.hlines(y=190,xmin=0,xmax=2000,lw=3,linestyles='--')
plt.text(x=900,y=220,s='Horizontal line crossing 5 vertical lines',fontsize=20)
#plt.grid(True)
plt.show()

# %% [markdown]
# Hierarchical Clustering

# %%
plt.figure(figsize=(12,7))
plt.title('Loss of Profits',fontsize=20)
plt.xlabel('Invoice',fontsize=16)
plt.ylabel('Quantity',fontsize=16)
plt.legend(fontsize=16)
plt.grid(True)
plt.axhspan(ymin=60,ymax=100,xmin=0.4,xmax=0.96,alpha=0.3,color='yellow')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
